# %% [markdown]
# # 다양한 웹 다루기 (2)
# - 웹 사이트의 구성 요소에 따라 각각 다른 방식으로 프로그래밍 해야 효율적으로 코딩 가능

# %% [markdown]
# # 인스타그램 데이터 가져오기

# %%
from bs4 import BeautifulSoup
import requests
import json
import pandas as pd

# %%
query = '펭수'

# %%
# xhr file 만들기
insta_url = 'https://www.instagram.com/explore/tags/'
search_query = query + '/'
javascript_query = '?__a=1'
search_url = insta_url + search_query + javascript_query

# %%
jsSearchUrl = insta_url + query
print(jsSearchUrl)
browser.get(jsSearchUrl)
# Out:
# https://www.instagram.com/explore/tags/펭수

# %%
htmlContent = requests.get(search_url).json() # xhr file url

# %%
htmlContent
# Out:
# {'graphql': {'hashtag': {'id': '17843761471003287',
#    'name': '펭수',
#    'allow_following': False,
#    'is_following': False,
#    'is_top_media_only': False,
#    'profile_pic_url': 'https://scontent-gmp1-1.cdninstagram.com/v/t51.2885-15/e35/c0.179.1440.1440a/s150x150/82125369_179362049826116_8016708949594259630_n.jpg?_nc_ht=scontent-gmp1-1.cdninstagram.com&_nc_cat=108&_nc_ohc=dk5rawHRReQAX_zehfY&oh=f7fdc60cf84b294a3709696032fe59c0&oe=5EBE08EF',
#    'edge_hashtag_to_media': {'count': 107721,
#     'page_info': {'has_next_page': True,
#      'end_cursor': 'QVFDWmtoY1ItNnFua0dKN0h1enRqMzcwU0VXdDRkSHpLSHJ3eUlPU0lzaFRwd1BpVjloLVBLZ0tvTVVCV2pBdzlGb1FUS2Q0b2MxQTFQYXBXOTJUdmtOcA=='},
#     'edges': [{'node': {'comments_disabled': False,
#        '__typename': 'GraphSidecar',
#        'id': '2226687105925663537',
# ...

# %%
htmlContent.keys()
# Out:
# dict_keys(['graphql'])

# %%
htmlContent.values()
# Out:
# dict_values([{'hashtag': {'id': '17843761471003287', 'name': '펭수', 'allow_following': False, 'is_following': False, 'is_top_media_only': False, 'profile_pic_url': 'https://scontent-gmp1-1.cdninstagram.com/v/t51.2885-15/e35/c0.179.1440.1440a/s150x150/82125369_179362049826116_8016708949594259630_n.jpg?_nc_ht=scontent-gmp1-1.cdninstagram.com&_nc_cat=108&_nc_ohc=dk5rawHRReQAX_zehfY&oh=f7fdc60cf84b294a3709696032fe59c0&oe=5EBE08EF', 'edge_hashtag_to_media': {'count': 107721, 'page_info': {'has_next_page': True, 'end_cursor': 'QVFDWmtoY1ItNnFua0dKN0h1enRqMzcwU0VXdDRkSHpLSHJ3eUlPU0lzaFRwd1BpVjloLVBLZ0tvTVVCV2pBdzlGb1FUS2Q0b2MxQTFQYXBXOTJUdmtOcA=='}, 'edges': [{'node': {'comments_disabled': False, '__typename': 'GraphSidecar', 'id': '2226687105925663537', 'edge_media_to_caption': {'edges': [{'node': {'text': 'ᴾᴱᴺᴳˢᴼᴼ🐧 ⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n#펭수 #giantpengtv #pengsoo #자이언트펭tv #남극참치 #동원참치 #콜라보 #collaboration #홈플러스 #드디어 #get #kpenguin #펭하 #이건맛의대참치 #어제 #昨日 #yesterday \n그디어 펭수참치 #겟
# ...

# %% [markdown]
# # 데이터 조회 과정

# %%
htmlContent['graphql']
# Out:
# {'hashtag': {'id': '17843761471003287',
#   'name': '펭수',
#   'allow_following': False,
#   'is_following': False,
#   'is_top_media_only': False,
#   'profile_pic_url': 'https://scontent-gmp1-1.cdninstagram.com/v/t51.2885-15/e35/c0.179.1440.1440a/s150x150/82125369_179362049826116_8016708949594259630_n.jpg?_nc_ht=scontent-gmp1-1.cdninstagram.com&_nc_cat=108&_nc_ohc=dk5rawHRReQAX_zehfY&oh=f7fdc60cf84b294a3709696032fe59c0&oe=5EBE08EF',
#   'edge_hashtag_to_media': {'count': 107721,
#    'page_info': {'has_next_page': True,
#     'end_cursor': 'QVFDWmtoY1ItNnFua0dKN0h1enRqMzcwU0VXdDRkSHpLSHJ3eUlPU0lzaFRwd1BpVjloLVBLZ0tvTVVCV2pBdzlGb1FUS2Q0b2MxQTFQYXBXOTJUdmtOcA=='},
#    'edges': [{'node': {'comments_disabled': False,
#       '__typename': 'GraphSidecar',
#       'id': '2226687105925663537',
# ...

# %%
htmlContent['graphql'].keys()
# Out:
# dict_keys(['hashtag'])

# %%
htmlContent['graphql']['hashtag']
# Out:
# {'id': '17843761471003287',
#  'name': '펭수',
#  'allow_following': False,
#  'is_following': False,
#  'is_top_media_only': False,
#  'profile_pic_url': 'https://scontent-gmp1-1.cdninstagram.com/v/t51.2885-15/e35/c0.179.1440.1440a/s150x150/82125369_179362049826116_8016708949594259630_n.jpg?_nc_ht=scontent-gmp1-1.cdninstagram.com&_nc_cat=108&_nc_ohc=dk5rawHRReQAX_zehfY&oh=f7fdc60cf84b294a3709696032fe59c0&oe=5EBE08EF',
#  'edge_hashtag_to_media': {'count': 107721,
#   'page_info': {'has_next_page': True,
#    'end_cursor': 'QVFDWmtoY1ItNnFua0dKN0h1enRqMzcwU0VXdDRkSHpLSHJ3eUlPU0lzaFRwd1BpVjloLVBLZ0tvTVVCV2pBdzlGb1FUS2Q0b2MxQTFQYXBXOTJUdmtOcA=='},
#   'edges': [{'node': {'comments_disabled': False,
#      '__typename': 'GraphSidecar',
#      'id': '2226687105925663537',
# ...

# %%
htmlContent['graphql']['hashtag'].keys()
# Out:
# dict_keys(['id', 'name', 'allow_following', 'is_following', 'is_top_media_only', 'profile_pic_url', 'edge_hashtag_to_media', 'edge_hashtag_to_top_posts', 'edge_hashtag_to_content_advisory', 'edge_hashtag_to_related_tags', 'edge_hashtag_to_null_state'])

# %%
htmlContent['graphql']['hashtag']['edge_hashtag_to_media']
# Out:
# {'count': 107721,
#  'page_info': {'has_next_page': True,
#   'end_cursor': 'QVFDWmtoY1ItNnFua0dKN0h1enRqMzcwU0VXdDRkSHpLSHJ3eUlPU0lzaFRwd1BpVjloLVBLZ0tvTVVCV2pBdzlGb1FUS2Q0b2MxQTFQYXBXOTJUdmtOcA=='},
#  'edges': [{'node': {'comments_disabled': False,
#     '__typename': 'GraphSidecar',
#     'id': '2226687105925663537',
#     'edge_media_to_caption': {'edges': [{'node': {'text': 'ᴾᴱᴺᴳˢᴼᴼ🐧 ⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n#펭수 #giantpengtv #pengsoo #자이언트펭tv #남극참치 #동원참치 #콜라보 #collaboration #홈플러스 #드디어 #get #kpenguin #펭하 #이건맛의대참치 #어제 #昨日 #yesterday \n그디어 펭수참치 #겟 !!!! 세번째사진에있는 펭수 진짜 너무 훔쳐오고싶었다 🤣🤣'}}]},
#     'shortcode': 'B7myCAWpEsx',
#     'edge_media_to_comment': {'count': 0},
#     'taken_at_timestamp': 1579661809,
#     'dimensions': {'height': 810, 'width': 1080},
# ...

# %%
htmlContent['graphql']['hashtag']['edge_hashtag_to_media'].keys()
# Out:
# dict_keys(['count', 'page_info', 'edges'])

# %%
htmlContent['graphql']['hashtag']['edge_hashtag_to_media']['count']
# Out:
# 107721

# %%
htmlContent['graphql']['hashtag']['edge_hashtag_to_media']['page_info']
# Out:
# {'has_next_page': True,
#  'end_cursor': 'QVFDWmtoY1ItNnFua0dKN0h1enRqMzcwU0VXdDRkSHpLSHJ3eUlPU0lzaFRwd1BpVjloLVBLZ0tvTVVCV2pBdzlGb1FUS2Q0b2MxQTFQYXBXOTJUdmtOcA=='}

# %%
htmlContent['graphql']['hashtag']['edge_hashtag_to_media']['edges']
# Out:
# [{'node': {'comments_disabled': False,
#    '__typename': 'GraphSidecar',
#    'id': '2226687105925663537',
#    'edge_media_to_caption': {'edges': [{'node': {'text': 'ᴾᴱᴺᴳˢᴼᴼ🐧 ⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n#펭수 #giantpengtv #pengsoo #자이언트펭tv #남극참치 #동원참치 #콜라보 #collaboration #홈플러스 #드디어 #get #kpenguin #펭하 #이건맛의대참치 #어제 #昨日 #yesterday \n그디어 펭수참치 #겟 !!!! 세번째사진에있는 펭수 진짜 너무 훔쳐오고싶었다 🤣🤣'}}]},
#    'shortcode': 'B7myCAWpEsx',
#    'edge_media_to_comment': {'count': 0},
#    'taken_at_timestamp': 1579661809,
#    'dimensions': {'height': 810, 'width': 1080},
#    'display_url': 'https://scontent-gmp1-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/82096960_817830161974117_2548661492496193654_n.jpg?_nc_ht=scontent-gmp1-1.cdninstagram.com&_nc_cat=101&_nc_ohc=0ZFfJnKFoY0AX-Fo_K2&oh=533b38429db79a84688e602700d6bd1a&oe=5EBC698C',
#    'edge_liked_by': {'count': 0},
#    'edge_media_preview_like': {'count': 0},
#    'owner': {'id': '761059776'},
# ...

# %%
htmlContent['graphql']['hashtag']['edge_hashtag_to_media']['edges']
# Out:
# [{'node': {'comments_disabled': False,
#    '__typename': 'GraphSidecar',
#    'id': '2226687105925663537',
#    'edge_media_to_caption': {'edges': [{'node': {'text': 'ᴾᴱᴺᴳˢᴼᴼ🐧 ⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n#펭수 #giantpengtv #pengsoo #자이언트펭tv #남극참치 #동원참치 #콜라보 #collaboration #홈플러스 #드디어 #get #kpenguin #펭하 #이건맛의대참치 #어제 #昨日 #yesterday \n그디어 펭수참치 #겟 !!!! 세번째사진에있는 펭수 진짜 너무 훔쳐오고싶었다 🤣🤣'}}]},
#    'shortcode': 'B7myCAWpEsx',
#    'edge_media_to_comment': {'count': 0},
#    'taken_at_timestamp': 1579661809,
#    'dimensions': {'height': 810, 'width': 1080},
#    'display_url': 'https://scontent-gmp1-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/82096960_817830161974117_2548661492496193654_n.jpg?_nc_ht=scontent-gmp1-1.cdninstagram.com&_nc_cat=101&_nc_ohc=0ZFfJnKFoY0AX-Fo_K2&oh=533b38429db79a84688e602700d6bd1a&oe=5EBC698C',
#    'edge_liked_by': {'count': 0},
#    'edge_media_preview_like': {'count': 0},
#    'owner': {'id': '761059776'},
# ...

# %%
len(htmlContent['graphql']['hashtag']['edge_hashtag_to_media']['edges'])
# Out:
# 64

# %%
type(htmlContent['graphql']['hashtag']['edge_hashtag_to_media']['edges'])
# Out:
# list

# %%
htmlContent['graphql']['hashtag']['edge_hashtag_to_media']['edges'][0]
# Out:
# {'node': {'comments_disabled': False,
#   '__typename': 'GraphSidecar',
#   'id': '2226687105925663537',
#   'edge_media_to_caption': {'edges': [{'node': {'text': 'ᴾᴱᴺᴳˢᴼᴼ🐧 ⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n#펭수 #giantpengtv #pengsoo #자이언트펭tv #남극참치 #동원참치 #콜라보 #collaboration #홈플러스 #드디어 #get #kpenguin #펭하 #이건맛의대참치 #어제 #昨日 #yesterday \n그디어 펭수참치 #겟 !!!! 세번째사진에있는 펭수 진짜 너무 훔쳐오고싶었다 🤣🤣'}}]},
#   'shortcode': 'B7myCAWpEsx',
#   'edge_media_to_comment': {'count': 0},
#   'taken_at_timestamp': 1579661809,
#   'dimensions': {'height': 810, 'width': 1080},
#   'display_url': 'https://scontent-gmp1-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/82096960_817830161974117_2548661492496193654_n.jpg?_nc_ht=scontent-gmp1-1.cdninstagram.com&_nc_cat=101&_nc_ohc=0ZFfJnKFoY0AX-Fo_K2&oh=533b38429db79a84688e602700d6bd1a&oe=5EBC698C',
#   'edge_liked_by': {'count': 0},
#   'edge_media_preview_like': {'count': 0},
#   'owner': {'id': '761059776'},
# ...

# %%
type(htmlContent['graphql']['hashtag']['edge_hashtag_to_media']['edges'][0])
# Out:
# dict

# %%
htmlContent['graphql']['hashtag']['edge_hashtag_to_media']['edges'][0].keys()
# Out:
# dict_keys(['node'])

# %%
htmlContent['graphql']['hashtag']['edge_hashtag_to_media']['edges'][0]['node']
# Out:
# {'comments_disabled': False,
#  '__typename': 'GraphSidecar',
#  'id': '2226687105925663537',
#  'edge_media_to_caption': {'edges': [{'node': {'text': 'ᴾᴱᴺᴳˢᴼᴼ🐧 ⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n⠀\n#펭수 #giantpengtv #pengsoo #자이언트펭tv #남극참치 #동원참치 #콜라보 #collaboration #홈플러스 #드디어 #get #kpenguin #펭하 #이건맛의대참치 #어제 #昨日 #yesterday \n그디어 펭수참치 #겟 !!!! 세번째사진에있는 펭수 진짜 너무 훔쳐오고싶었다 🤣🤣'}}]},
#  'shortcode': 'B7myCAWpEsx',
#  'edge_media_to_comment': {'count': 0},
#  'taken_at_timestamp': 1579661809,
#  'dimensions': {'height': 810, 'width': 1080},
#  'display_url': 'https://scontent-gmp1-1.cdninstagram.com/v/t51.2885-15/e35/s1080x1080/82096960_817830161974117_2548661492496193654_n.jpg?_nc_ht=scontent-gmp1-1.cdninstagram.com&_nc_cat=101&_nc_ohc=0ZFfJnKFoY0AX-Fo_K2&oh=533b38429db79a84688e602700d6bd1a&oe=5EBC698C',
#  'edge_liked_by': {'count': 0},
#  'edge_media_preview_like': {'count': 0},
#  'owner': {'id': '761059776'},
# ...

# %%
len(htmlContent['graphql']['hashtag']['edge_hashtag_to_media']['edges'][0]['node'])
# Out:
# 16

# %%
type(htmlContent['graphql']['hashtag']['edge_hashtag_to_media']['edges'][0]['node'])
# Out:
# dict

# %%
htmlContent['graphql']['hashtag']['edge_hashtag_to_media']['edges'][0]['node'].keys()
# Out:
# dict_keys(['comments_disabled', '__typename', 'id', 'edge_media_to_caption', 'shortcode', 'edge_media_to_comment', 'taken_at_timestamp', 'dimensions', 'display_url', 'edge_liked_by', 'edge_media_preview_like', 'owner', 'thumbnail_src', 'thumbnail_resources', 'is_video', 'accessibility_caption'])

# %%
htmlContent['graphql']['hashtag']['edge_hashtag_to_media']['edges'][0]['node']['thumbnail_resources']
# Out:
# [{'src': 'https://scontent-gmp1-1.cdninstagram.com/v/t51.2885-15/e35/c180.0.1080.1080a/s150x150/82096960_817830161974117_2548661492496193654_n.jpg?_nc_ht=scontent-gmp1-1.cdninstagram.com&_nc_cat=101&_nc_ohc=0ZFfJnKFoY0AX-Fo_K2&oh=c28221694ab13d01bdfacbd661c5e248&oe=5EB71306',
#   'config_width': 150,
#   'config_height': 150},
#  {'src': 'https://scontent-gmp1-1.cdninstagram.com/v/t51.2885-15/e35/c180.0.1080.1080a/s240x240/82096960_817830161974117_2548661492496193654_n.jpg?_nc_ht=scontent-gmp1-1.cdninstagram.com&_nc_cat=101&_nc_ohc=0ZFfJnKFoY0AX-Fo_K2&oh=5710c5094482cd0aa530346f04492044&oe=5ECE864C',
#   'config_width': 240,
#   'config_height': 240},
#  {'src': 'https://scontent-gmp1-1.cdninstagram.com/v/t51.2885-15/e35/c180.0.1080.1080a/s320x320/82096960_817830161974117_2548661492496193654_n.jpg?_nc_ht=scontent-gmp1-1.cdninstagram.com&_nc_cat=101&_nc_ohc=0ZFfJnKFoY0AX-Fo_K2&oh=e221f664ce1d29f60aec1d30c79190dc&oe=5ECC3DF6',
#   'config_width': 320,
#   'config_height': 320},
# ...

# %%
len(htmlContent['graphql']['hashtag']['edge_hashtag_to_media']['edges'][0]['node']['thumbnail_resources'])
# Out:
# 5

# %%
htmlContent['graphql']['hashtag']['edge_hashtag_to_media']['edges'][0]['node']['thumbnail_resources'][0]
# Out:
# {'src': 'https://scontent-gmp1-1.cdninstagram.com/v/t51.2885-15/e35/c180.0.1080.1080a/s150x150/82096960_817830161974117_2548661492496193654_n.jpg?_nc_ht=scontent-gmp1-1.cdninstagram.com&_nc_cat=101&_nc_ohc=0ZFfJnKFoY0AX-Fo_K2&oh=c28221694ab13d01bdfacbd661c5e248&oe=5EB71306',
#  'config_width': 150,
#  'config_height': 150}

# %%
type(htmlContent['graphql']['hashtag']['edge_hashtag_to_media']['edges'][0]['node']['thumbnail_resources'][0])
# Out:
# dict

# %%
htmlContent['graphql']['hashtag']['edge_hashtag_to_media']['edges'][0]['node']['thumbnail_resources'][0].keys()
# Out:
# dict_keys(['src', 'config_width', 'config_height'])

# %%
htmlContent['graphql']['hashtag']['edge_hashtag_to_media']['edges'][0]['node']['thumbnail_resources'][0]['src']
# Out:
# 'https://scontent-gmp1-1.cdninstagram.com/v/t51.2885-15/e35/c180.0.1080.1080a/s150x150/82096960_817830161974117_2548661492496193654_n.jpg?_nc_ht=scontent-gmp1-1.cdninstagram.com&_nc_cat=101&_nc_ohc=0ZFfJnKFoY0AX-Fo_K2&oh=c28221694ab13d01bdfacbd661c5e248&oe=5EB71306'

# %%
# next page, end cursor variable
next_page = htmlContent['graphql']['hashtag']['edge_hashtag_to_media']['page_info']['has_next_page']
print(next_page)
# Out:
# True
